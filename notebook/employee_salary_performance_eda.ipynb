# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("employee_data.csv")

# %%
df
# Out:
#       Name Department  Salary  Experience  Performance
# 0    Alice         HR   45000           2           78
# 1      Bob         IT   65000           5           88
# 2  Charlie    Finance   55000           4           82
# 3    Diana         IT   70000           6           95
# 4    Ethan      Sales   50000           3           75
# 5    Fiona         HR   48000           2           80
# 6   George    Finance   60000           5           90
# 7   Hannah         IT   72000           7           92

# %%
df.describe()
# Out:
#             Salary  Experience  Performance
# count      8.00000    8.000000     8.000000
# mean   58125.00000    4.250000    85.000000
# std    10246.07939    1.832251     7.230886
# min    45000.00000    2.000000    75.000000
# 25%    49500.00000    2.750000    79.500000
# 50%    57500.00000    4.500000    85.000000
# 75%    66250.00000    5.250000    90.500000
# max    72000.00000    7.000000    95.000000

# %%
df["Salary"].mean()
# Out:
# 58125.0

# %%
df["Performance"].mean()
# Out:
# 85.0

# %%
df["Experience"].mean()
# Out:
# 4.25

# %%
df["Department"].value_counts()
# Out:
# Department
# IT         3
# HR         2
# Finance    2
# Sales      1
# Name: count, dtype: int64

# %%
df["Department"].value_counts().plot(
    kind="bar"
)

plt.title("Employee Count by Department")
plt.xlabel("Department")
plt.ylabel("Number of Employees")
plt.show()

# %%
avg_salary = df.groupby("Department")["Salary"].mean()

avg_salary
# Out:
# Department
# Finance    57500.0
# HR         46500.0
# IT         69000.0
# Sales      50000.0
# Name: Salary, dtype: float64

# %%
avg_salary.plot(
    kind="bar"
)

plt.title("Average Salary by Department")
plt.xlabel("Department")
plt.ylabel("Average Salary")
plt.show()

# %%
avg_salary.plot(
    kind="barh"
)

plt.title("Average Salary by Department")
plt.xlabel("Average Salary")
plt.ylabel("Department")
plt.show()

# %%
df["Salary"].plot(
    kind="hist",
    bins=10
)

plt.title("Distribution of Employee Salaries")
plt.xlabel("Salary")
plt.ylabel("Number of Employees")
plt.show()

# %%
df["Performance"].plot(
    kind="hist",
    bins=5
)

plt.title("Distribution of Performance Scores")
plt.xlabel("Performance Score")
plt.ylabel("Number of Employees")
plt.show()

# %%
plt.scatter(
    df["Experience"],
    df["Salary"]
)

plt.title("Salary vs Experience")
plt.xlabel("Experience (Years)")
plt.ylabel("Salary")
plt.show()

# %%
df["Experience"].corr(df["Salary"])
# Out:
# 0.9797303684658326

# %%
df["Salary"].plot(
    kind="box"
)

plt.title("Salary Distribution and Outliers")
plt.ylabel("Salary")
plt.show()

# %%
avg_performance = df.groupby("Department")["Performance"].mean()

avg_performance
# Out:
# Department
# Finance    86.000000
# HR         79.000000
# IT         91.666667
# Sales      75.000000
# Name: Performance, dtype: float64

# %%
avg_performance.plot(
    kind="bar"
)

plt.title("Average Performance by Department")
plt.xlabel("Department")
plt.ylabel("Average Performance")
plt.show()

# %%
df["Department"].value_counts()
# Out:
# Department
# IT         3
# HR         2
# Finance    2
# Sales      1
# Name: count, dtype: int64

# %%
df.groupby("Department")["Salary"].mean()
# Out:
# Department
# Finance    57500.0
# HR         46500.0
# IT         69000.0
# Sales      50000.0
# Name: Salary, dtype: float64

# %%
df.groupby("Department")["Performance"].mean()
# Out:
# Department
# Finance    86.000000
# HR         79.000000
# IT         91.666667
# Sales      75.000000
# Name: Performance, dtype: float64

# %%
df["Experience"].mean()
# Out:
# 4.25

# %%
df["Experience"].corr(df["Salary"])
# Out:
# 0.9797303684658326

# %%
department_summary = df.groupby("Department").agg(
    Employee_Count=("Name", "count"),
    Average_Salary=("Salary", "mean"),
    Average_Performance=("Performance", "mean"),
    Average_Experience=("Experience", "mean")
)

department_summary
# Out:
#             Employee_Count  Average_Salary  Average_Performance  \
# Department
# Finance                  2         57500.0            86.000000
# HR                       2         46500.0            79.000000
# IT                       3         69000.0            91.666667
# Sales                    1         50000.0            75.000000
#
#             Average_Experience
# Department
# Finance                    4.5
# HR                         2.0
# IT                         6.0
# Sales                      3.0

# %%
department_summary.sort_values(
    "Average_Performance",
    ascending=False
)
# Out:
#             Employee_Count  Average_Salary  Average_Performance  \
# Department
# IT                       3         69000.0            91.666667
# Finance                  2         57500.0            86.000000
# HR                       2         46500.0            79.000000
# Sales                    1         50000.0            75.000000
#
#             Average_Experience
# Department
# IT                         6.0
# Finance                    4.5
# HR                         2.0
# Sales                      3.0

# %%
department_summary.sort_values(
    "Average_Salary",
    ascending=False
)
# Out:
#             Employee_Count  Average_Salary  Average_Performance  \
# Department
# IT                       3         69000.0            91.666667
# Finance                  2         57500.0            86.000000
# Sales                    1         50000.0            75.000000
# HR                       2         46500.0            79.000000
#
#             Average_Experience
# Department
# IT                         6.0
# Finance                    4.5
# Sales                      3.0
# HR                         2.0
